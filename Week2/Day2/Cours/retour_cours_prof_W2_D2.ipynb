# %%
import pandas as pd

json_data = pd.read_json('https://jsonplaceholder.typicode.com/posts')
json_data.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
json_data.size
# Out:
# 400

# %%
excel_data = pd.read_excel('sample_data.xls', index_col=0)
print(excel_data.head())

# %%
json_data.to_json('json_data_s.json', orient='split')

# %%
json_data.to_json('json_data_i.json', orient='index')

# %% [markdown]
# ## Challenge Lecture 1

# %%
#Import grade.csv from this website and show the initial few rows.
from google.colab import files
uploaded = files.upload('/content/drive/MyDrive/Gen-AI_2025')
# Out:
#      <input type="file" id="files-ef638f81-7575-4518-b59e-2112356ce5d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef638f81-7575-4518-b59e-2112356ce5d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Gen-AI_2025/grades.csv')
df.head()
# Out:
#   Last name      "First name"                 "SSN"         "Test1"   "Test2"  \
# 0   Alfalfa        "Aloysius"         "123-45-6789"            40.0      90.0
# 1    Alfred      "University"         "123-12-1234"            41.0      97.0
# 2     Gerty          "Gramma"         "567-89-0123"            41.0      80.0
# 3   Android        "Electric"         "087-65-4321"            42.0      23.0
# 4   Bumpkin            "Fred"         "456-78-9012"            43.0      78.0
#
#     "Test3"   "Test4"   "Final"  "Grade"
# 0     100.0      83.0      49.0     "D-"
# 1      96.0      97.0      48.0     "D+"
# 2      60.0      40.0      44.0      "C"
# 3      36.0      45.0      47.0     "B-"
# 4      88.0      77.0      45.0     "A-"

# %%
#Expot in the propre file path
df.to_json('/content/drive/MyDrive/Gen-AI_2025/json_grades.json', orient='split')

# %%
# stores data in a way that requires specifying the same orient when reading with read_json.
df1 = pd.read_json('/content/drive/MyDrive/Gen-AI_2025/json_grades.json', orient='split') #ajouter orient='split'

# %%
df1.head()
# Out:
#   Last name      "First name"                 "SSN"         "Test1"   "Test2"  \
# 0   Alfalfa        "Aloysius"         "123-45-6789"            40.0        90
# 1    Alfred      "University"         "123-12-1234"            41.0        97
# 2     Gerty          "Gramma"         "567-89-0123"            41.0        80
# 3   Android        "Electric"         "087-65-4321"            42.0        23
# 4   Bumpkin            "Fred"         "456-78-9012"            43.0        78
#
#     "Test3"   "Test4"   "Final"  "Grade"
# 0       100        83      49.0     "D-"
# 1        96        97      48.0     "D+"
# 2        60        40      44.0      "C"
# 3        36        45      47.0     "B-"
# 4        88        77      45.0     "A-"

# %%
df1.size
# Out:
# 144

# %%
df1.shape
# Out:
# (16, 9)

# %% [markdown]
# ## Challenge lecture 4
# ### 3. Handling Large Datasets:

# %%
for chunk in pd.read_csv('/content/drive/MyDrive/Gen-AI_2025/grades.csv', chunksize=100):
  chunk.to_csv('/content/drive/MyDrive/Gen-AI_2025/output_chunk.csv', mode='a')

# %% [markdown]
# ### Format Parquet et HDF5

# %%
df.to_parquet('/content/drive/MyDrive/Gen-AI_2025/large_data.parquet')

# %%
df.to_json('/content/drive/MyDrive/Gen-AI_2025/large_data.json')

# %% [markdown]
#  use `%%time` to measure the execution time for saving the DataFrame to Parquet and JSON formats:

# %%
# %%time
df.to_parquet('/content/drive/MyDrive/Gen-AI_2025/large_data2.parquet')
# Out:
# CPU times: user 5.92 ms, sys: 164 µs, total: 6.09 ms
# Wall time: 21.7 ms

# %%
# %%time
df.to_json('/content/drive/MyDrive/Gen-AI_2025/large_data2.json')
# Out:
# CPU times: user 1.07 ms, sys: 711 µs, total: 1.78 ms
# Wall time: 26.8 ms

# %% [markdown]
# ### **HDF5**

# %%
df.to_hdf('/content/drive/MyDrive/Gen-AI_2025/large_data_3.hdf5', key='df')
# Out:
# /tmp/ipython-input-17491717.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Last name', ' "First name"', ' "SSN"', '        "Test1"', ' "Final"',
#        ' "Grade"'],
#       dtype='object')]
#
#   df.to_hdf('/content/drive/MyDrive/Gen-AI_2025/large_data_3.hdf5', key='df')
