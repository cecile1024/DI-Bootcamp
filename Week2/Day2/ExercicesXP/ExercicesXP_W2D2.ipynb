# %% [markdown]
# Exercises XP Week2 Day 2

# %% [markdown]
# # **Exercise 1: Identifying Data Types**
#
# The structured data sources are :
# - A company’s financial reports stored in an Excel file.
# - Inventory data in a relational database.
#
#
# The unstructure data sources are:
# - Photographs uploaded to a social media platform.
# - A collection of news articles on a website.
# - Recorded interviews from a market research study.

# %% [markdown]
# # **Exercise 2: Transformation Exercise**
# Suggestions to structure the following  sources of unstructured data.
#
# - A series of blog posts about travel experiences.
# Analyze the blog posts to extract and organize structured information such as: author, publication date, travel destination, travel duration, type of trip (road trip, trekking, cruise, etc.), people involved, places visited, cultural aspects, overall appreciation, and presence of photos. Use natural language processing (NLP) to automatically detect key entities (locations, people, dates) and sentiments.
#
# - Audio recordings of customer service calls.
# Label the recordings with metadata (date, time, duration, agent, customer ID).
# Convert the audio to text using speech-to-text software.
# Then analyze the transcribed text to extract: type of issue or claim, product concerned, nature of the questions and answers, tone or sentiment, and overall customer satisfaction.
# Store both the audio metadata and text analysis results in a relational table for cross-analysis.
#
# - Handwritten notes from a brainstorming session.
# Transcribe or digitize the handwritten notes using OCR (Optical Character Recognition) or manual typing.
# Then label each note with: theme, level of relevance, priority, keywords, and contributors.
# Group similar ideas through clustering or thematic coding to facilitate synthesis.
#
# - A video tutorial on cooking.
# Transcribe the audio into text using speech recognition.
# Extract structured elements: list of ingredients, required materials, numbered preparation steps, estimated time, and difficulty level.

# %% [markdown]
#  **!!!For Exercises 3, 4, and 6, the code unnecessarily downloads and extracts the zip files to Google Drive before reading the CSV/JSON files.  Pandas can read directly from a zipped file using pd.read_csv('zipfile://path/to/your/file.zip').  This would significantly improve performance and reduce complexity.**
#
# **The repetition of code for downloading and unzipping files in Exercises 3, 4, and 6 can be refactored into a function to improve readability and maintainability.**

# %% [markdown]
# **The save_path is hardcoded, which reduces flexibility. Consider making it a parameter.**
#
# **Consider using more descriptive variable names, especially for file paths.**

# %%
# Exercise 3 : Import a file from Kaggle

url='https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/train.zip'

# # Monter mon Google Drive si necessaire
# from google.colab import drive
# drive.mount('/content/drive')

# Verifier ou créer le dossier cible
import os #interagir avec ton système d’exploitation
save_path ='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP'
os.makedirs(save_path, exist_ok=True)# crée le dossier s’il n’existe pas déjà
zip_path = os.path.join(save_path, "train.zip")

# Télécharger le fichier .zip depuis l’URL et le placer dans le dossier
import urllib.request # used to open URLs
urllib.request.urlretrieve(url, zip_path) #télécharger un fichier depuis une URL et à l’enregistrer localement
print("Fichier téléchargé dans :", zip_path)


# Dézipper le fichier dans le même dossier
import zipfile
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(save_path)
print("Fichiers extraits dans :", save_path)

# Créer un DataFrame à partir du fichier train.csv
import pandas as pd
csv_path = os.path.join(save_path, "train.csv")
train_data = pd.read_csv(csv_path)
train_data.head()
# Out:
# Fichier téléchargé dans : /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/train.zip
# Fichiers extraits dans : /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# exercice 4

url_fichier_zip='https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/Iris_dataset.zip'

# Verifier ou créer le dossier cible
import os #interagir avec ton système d’exploitation
save_path ='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP'
os.makedirs(save_path, exist_ok=True)# crée le dossier s’il n’existe pas déjà
zip_path = os.path.join(save_path, "Iris_dataset.zip")

# Télécharger le fichier .zip depuis l’URL et le placer dans le dossier
import urllib.request # used to open URLs
urllib.request.urlretrieve(url_fichier_zip, zip_path) #télécharger un fichier depuis une URL et à l’enregistrer localement
print("Fichier téléchargé dans :", zip_path)

# Dézipper le fichier dans le même dossier
import zipfile
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(save_path)
print("Fichiers extraits dans :", save_path)

# Créer un DataFrame à partir du fichier train.csv
import pandas as pd
Iris_dataset=pd.read_csv('/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/Iris_dataset.csv')
Iris_dataset.head()
# Out:
# Fichier téléchargé dans : /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/Iris_dataset.zip
# Fichiers extraits dans : /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
#Exercice 5
# Create a simple dataframe
import pandas as pd
data_ex5=[[11,12,13],['f','g','h'],['Cecile','Billie','child']] # chaque sous-liste est une ligne
df_ex5=pd.DataFrame(data_ex5).T # .T pour prendre la transposée

# Export the dataframe to an excel file.
df_ex5.to_excel('/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/df_ex5.xlsx')

# Export the dataframe to a JSON file
df_ex5.to_json('/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/df_ex5.json')

# %% [markdown]
# **For Exercise 6, the !unzip command is not necessary since zipfile.ZipFile already extracts the contents. Remove this line.**
#
# **Avoid saving to a personal Google Drive path, as this limits reproducibility for others**
#
# **the notebook is saving to an absolute path on Google Drive, rather than a relative path which would be preferred. **
#
# **Downloading to the google drive is also unnecessary since it can be read directly from URL.**
#
#
# - readability: The code is generally readable but could be improved by refactoring repeated code blocks into functions and using more descriptive variable names. The comments are helpful but could be more concise.
# - performance: The code's performance is acceptable, but downloading and extracting the ZIP files before reading the data is inefficient. Pandas can directly read from zipped files, which would be much faster. Using functions to avoid duplicating code would also lead to performance gains.

# %%
# Exercise 6: Reading JSON Data
url_fichier2_zip='https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/posts.zip'

# Verifier ou créer le dossier cible
import os #interagir avec ton système d’exploitation
save_path ='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP'
os.makedirs(save_path, exist_ok=True)# crée le dossier s’il n’existe pas déjà
zip_path = os.path.join(save_path, "posts.zip")

# Télécharger le fichier .zip depuis l’URL et le placer dans le dossier
import urllib.request # used to open URLs
urllib.request.urlretrieve(url_fichier2_zip, zip_path) #télécharger un fichier depuis une URL et à l’enregistrer localement
print("Fichier téléchargé dans :", zip_path)

# Dézipper le fichier dans le même dossier
import zipfile
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(save_path)
print("Fichiers extraits dans :", save_path)

# Décompresser le fichier ZIP dans le même dossier (-d ) pour decompresser dossier destinataire
# !unzip /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/posts.zip -d /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP

# Display the first five entries of the data.
import pandas as pd
df_posts=pd.read_json('/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/posts.json')
df_posts.head()
# Out:
# Fichier téléchargé dans : /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/posts.zip
# Fichiers extraits dans : /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP
# Archive:  /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/posts.zip
# replace /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/posts.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day2/ExercicesXP/posts.json
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
# ...
