# %%
Exercices XP Week2 Day1

# %% [markdown]
# # **Exercice 1 : introduction to data analysis**

# %% [markdown]
# L’importance et les applications de l’analyse de données
#
# 1)	Qu’est-ce que l’analyse de données ?
#
# L’analyse de données désigne l’ensemble des méthodes qui consistent à collecter, nettoyer, organiser et interpréter des informations brutes afin d’en extraire des tendances, des corrélations et des connaissances utiles. Elle permet de transformer de simples données en savoir exploitable, servant à comprendre des phénomènes, résoudre des problèmes et guider la prise de décision. Aujourd’hui, cette compétence n’est plus réservée aux chercheurs ou aux statisticiens : elle est devenue un socle commun de la transformation numérique, présent dans tous les secteurs d’activité.
#
# 2)	Pourquoi l’analyse de données est-elle importante dans les contextes modernes ?
#
# Nous vivons aujourd’hui dans le monde de la data. Les données massives sont générées au moindre de nos comportements ; l’informatisation des connaissances et l’automatisation des processus en génère tout autant, dans tous les domaines. L’analyse de ces données permet de donner du sens à cette masse d’informations, en identifiant les éléments pertinents pour agir de manière plus efficace et plus juste. Son importance est multiple :
# -	Elle rend possible une prise de décision fondée sur des preuves plutôt que sur l’intuition.
# -	Elle contribue à optimiser les processus et à innover dans les entreprises et les institutions publiques.
# -	Elle aide à mieux comprendre les comportements humains et à anticiper les tendances sociales, économiques ou sanitaires.
# Dans un contexte où les organisations doivent s’adapter rapidement, l’analyse de données est devenue un levier stratégique de compétitivité et d’intelligence collective.
#
# 3)	Trois domaines d’application actuels:
#
# 1.	Santé et recherche biomédicale
# L’analyse de données médicales aide à repérer des facteurs de risque, améliorer les diagnostics précoces ou adapter les traitements. Par exemple, les hôpitaux utilisent des modèles prédictifs pour anticiper les besoins en lits ou suivre l’évolution d’une épidémie.
# 2.	Marketing et expérience client
# Les entreprises exploitent les données comportementales pour mieux comprendre les besoins de leurs clients. Les plateformes comme Netflix ou Amazon analysent les historiques d’usage pour recommander des contenus personnalisés et améliorer la fidélisation.
# 3.	Finance et économie
# Les banques et les investisseurs recourent à des modèles analytiques pour détecter les fraudes, anticiper les risques ou guider leurs stratégies de placement. L’analyse en temps réel des marchés permet d’ajuster instantanément les décisions d’achat ou de vente.
#
# Conclusion
#
# L’analyse de données est bien plus qu’un ensemble d’outils techniques : c’est une nouvelle manière de penser et de comprendre le monde. Elle relie observation, raisonnement et action pour permettre des choix éclairés. Dans la santé, le commerce ou la finance, elle transforme les données en connaissance et en valeur, favorisant l’innovation et la responsabilité. À mesure que les volumes de données continuent de croître, la culture analytique devient une compétence essentielle pour les citoyens, les chercheurs et les décideurs de demain.

# %% [markdown]
# # **Exercice 2 : Dataset Loading and intial analysis**

# %%
import requests
import pandas as pd

# %%
CheminFichier1='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/How Much Sleep Do Americans/Time Americans Spend Sleeping.csv'
dataset_1=pd.read_csv(CheminFichier1)
dataset_1.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
dataset_1.info()
dataset_1.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB
#              index         Year  Period  Avg hrs per day sleeping  \
# count   945.000000   945.000000     945                945.000000
# unique         NaN          NaN       1                       NaN
# ...

# %%
print("\nSummary dataset_1 Generated by .describe() Method:")
print(dataset_1.describe())
# Out:
# Summary dataset_1 Generated by .describe() Method:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
type_of_day=set(dataset_1['Type of Days'])
print(type_of_day)
age_groupe=set(dataset_1['Age Group'])
print(age_groupe)
gender=set(dataset_1['Sex'])
print(gender)
# Out:
# {'Weekend days and holidays', 'All days', 'Nonholiday weekdays'}
# {'65 years and over', '35 to 44 years', '15 years and over', '45 to 54 years', '15 to 24 years', '55 to 64 years', '25 to 34 years'}
# {'Men', 'Both', 'Women'}

# %%
CheminFichier2='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/Global Trends in Mental Health Disorder/Mental health Depression disorder Data.csv'
dataset_2=pd.read_csv(CheminFichier2)
dataset_2.head()
# Out:
# /tmp/ipython-input-1060596848.py:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_2=pd.read_csv(CheminFichier2)
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# ...

# %%
dataset_2.info()
dataset_2.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB
# ...

# %%
CheminFichier3='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/Credit Card Approvals (Clean Data)/clean_dataset.csv'
dataset_3=pd.read_csv(CheminFichier3)
dataset_3.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
dataset_3.info()
dataset_3.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB
# ...

# %% [markdown]
# # Exercice 3 : identifying data *types*

# %% [markdown]
# objectif : pour chaque dataset précédents, idenitfierles colonnes avec des données quantitétives, et celles avec les données qualitatives

# %%
import pandas as pd
CheminFichier1='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/How Much Sleep Do Americans/Time Americans Spend Sleeping.csv'
dataset_1=pd.read_csv(CheminFichier1)

# %%
dataset_1.dtypes
# Out:
# index                         int64
# Year                          int64
# Period                       object
# Avg hrs per day sleeping    float64
# Standard Error              float64
# Type of Days                 object
# Age Group                    object
# Activity                     object
# Sex                          object
# dtype: object

# %%
quantitatives_dataset_1 = dataset_1.select_dtypes(include=['int64', 'float64']).columns
print("Colonnes quantitatives :")
print(list(quantitatives_dataset_1))
# Out:
# Colonnes quantitatives :
# ['index', 'Year', 'Avg hrs per day sleeping', 'Standard Error']

# %%
qualitatives_dataset1 = dataset_1.select_dtypes(include=['object', 'category']).columns
print("\nColonnes qualitatives dataset_1:")
print(list(qualitatives_dataset1))
# Out:
# Colonnes qualitatives dataset_1:
# ['Period', 'Type of Days', 'Age Group', 'Activity', 'Sex']

# %%
CheminFichier2='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/Global Trends in Mental Health Disorder/Mental health Depression disorder Data.csv'
dataset_2=pd.read_csv(CheminFichier2)
# Out:
# /tmp/ipython-input-614534487.py:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_2=pd.read_csv(CheminFichier2)

# %%
dataset_2.dtypes
# Out:
# index                          int64
# Entity                        object
# Code                          object
# Year                          object
# Schizophrenia (%)             object
# Bipolar disorder (%)          object
# Eating disorders (%)          object
# Anxiety disorders (%)        float64
# Drug use disorders (%)       float64
# Depression (%)               float64
# Alcohol use disorders (%)    float64
# dtype: object

# %%
quantitative_dataset_2=dataset_2.select_dtypes(include=['int64','float64'])
print("\nColonnes quantitatives dataset_2")
print(list(quantitative_dataset_2))
# Out:
# Colonnes quantitatives dataset_2
# ['index', 'Anxiety disorders (%)', 'Drug use disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)']

# %%
qualitative_dataset_2=dataset_2.select_dtypes(include=['object', 'category']).columns
print("\nColonnes qualitatives dataset_2")
print(list(qualitative_dataset_2))
# Out:
# Colonnes qualitatives dataset_2
# ['Entity', 'Code', 'Year', 'Schizophrenia (%)', 'Bipolar disorder (%)', 'Eating disorders (%)']

# %%
CheminFichier3='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/Credit Card Approvals (Clean Data)/clean_dataset.csv'
dataset_3=pd.read_csv(CheminFichier3)

# %%
dataset_3.dtypes
# Out:
# Gender              int64
# Age               float64
# Debt              float64
# Married             int64
# BankCustomer        int64
# Industry           object
# Ethnicity          object
# YearsEmployed     float64
# PriorDefault        int64
# Employed            int64
# CreditScore         int64
# DriversLicense      int64
# Citizen            object
# ZipCode             int64
# Income              int64
# Approved            int64
# dtype: object

# %%
quantitative_dataset_3=dataset_3.select_dtypes(include=['int64','float64'])
print("\nColonnes quantitatives dataset_3")
print(list(quantitative_dataset_3))
# Out:
# Colonnes quantitatives dataset_3
# ['Gender', 'Age', 'Debt', 'Married', 'BankCustomer', 'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore', 'DriversLicense', 'ZipCode', 'Income', 'Approved']

# %%
qualitative_dataset_3=dataset_3.select_dtypes(include=['object', 'category']).columns
print("\nColonnes qualitatives dataset_3")
print(list(qualitative_dataset_3))
# Out:
# Colonnes qualitatives dataset_3
# ['Industry', 'Ethnicity', 'Citizen']

# %% [markdown]
# # Exercice 4 : exploring Data *types*

# %%
# !pip install kaggle
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7955504e-5c36-4237-81fa-f505ff783241" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7955504e-5c36-4237-81fa-f505ff783241">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
Chemin_Iris_dataset='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/Iris Dataset/Iris.csv'
dataset_Iris=pd.read_csv(Chemin_Iris_dataset)
dataset_Iris
print("\nSummary dataset_Iris Generated by .describe() Method:")
print(dataset_Iris.describe())
# Out:
# Summary dataset_Iris Generated by .describe() Method:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
dataset_Iris.head()
dataset_Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
quantitative_dataset_Iris=dataset_Iris.select_dtypes(include=['int64','float64'])
print("\nColonnes quantitatives dataset_Iris")
print(list(quantitative_dataset_Iris))
# Out:
# Colonnes quantitatives dataset_Iris
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %% [markdown]
# * La colonne 'ID' renvoie au numero du sujet: 'ets un entier, et donc une donnée quantitative en apparence. On aurait pu choisir : S1, S2, etc.
# * Les colonnes 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'renvoient des mesures en centimètres, ce sont donc toutes des données quantitatives.

# %%
qualitative_dataset_Iris=dataset_Iris.select_dtypes(include=['object', 'category']).columns
print("\nColonnes qualitatives dataset_Iris")
print(list(qualitative_dataset_Iris))
# Out:
# Colonnes qualitatives dataset_Iris
# ['Species']

# %% [markdown]
# La donnée dans la colonne 'Species' renvoie au type d'iris, et est donc une données nominative, et donc qualitative.

# %% [markdown]
# #exercice 5 : Basic Data analysis with gooogle colab

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_Iris.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
#histogram with Matplotlib
plt.hist(dataset_Iris['SepalLengthCm'], bins=20, edgecolor='black')
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
# with seaborn
sns.histplot(data=dataset_Iris, x='SepalLengthCm', kde=True) #kde=True adds a smooth density curve.
plt.title("Distribution of Sepal Length")
plt.show()

# %%
#bar chart wit Matplotlib
dataset_Iris.groupby('Species')['SepalLengthCm'].mean().plot(kind='bar')
plt.title("Average Sepal Length per Species")
plt.ylabel("Mean Sepal Length (cm)")
plt.show()

# %%
# bar chat with Seaborn
sns.barplot(data=dataset_Iris, x='Species', y='SepalLengthCm', estimator='mean')
plt.title("Average Sepal Length per Species")
plt.show()

# %%
plt.plot(dataset_Iris['Species'], dataset_Iris['SepalLengthCm'])
plt.show()

# %% [markdown]
# # exercice 6 : Basic observation skills in data analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
CheminFichier1='/content/drive/MyDrive/00_bootcampGenIAML/DI-Bootcamp/Week2/Day1/Datasets/How Much Sleep Do Americans/Time Americans Spend Sleeping.csv'
dataset_1=pd.read_csv(CheminFichier1)
dataset_1.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
group_stats = dataset_1.groupby('Age Group')['Avg hrs per day sleeping'].agg(
    ['count', 'mean', 'median', 'std', 'min', 'max']
)
print("📋 Statistiques par groupe d'âge :")
print(group_stats)
# Out:
# 📋 Statistiques par groupe d'âge :
#                    count      mean  median       std   min    max
# Age Group
# 15 to 24 years       135  9.499259    9.34  0.516464  8.58  10.65
# 15 years and over    135  8.810296    8.67  0.410758  8.16   9.52
# 25 to 34 years       135  8.793111    8.65  0.522186  7.91   9.74
# 35 to 44 years       135  8.586222    8.41  0.501157  7.78   9.50
# 45 to 54 years       135  8.484074    8.36  0.488767  7.72   9.49
# 55 to 64 years       135  8.509259    8.43  0.344040  7.95   9.14
# 65 years and over    135  8.965852    8.95  0.155018  8.63   9.31

# %%
# avec seaborn
plt.figure(figsize=(8,6))
sns.boxplot(data=dataset_1, x='Age Group', y='Avg hrs per day sleeping', palette='Set2')

plt.title("Distribution des heures de sommeil selon le groupe d'âge")
plt.xlabel("Groupe d'âge")
plt.ylabel("Heures moyennes de sommeil par jour")
plt.show()
# Out:
# /tmp/ipython-input-1446250116.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dataset_1, x='Age Group', y='Avg hrs per day sleeping', palette='Set2')

# %% [markdown]
# It could be interesting to analyse 'average hours per day sleeping" per "age group"
